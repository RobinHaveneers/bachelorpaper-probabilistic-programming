# %%
# the first line tells Jupyter to place the figures directly in the notebook
# %matplotlib inline    
import matplotlib
import numpy as np
import mpl_toolkits.axisartist as AA

import matplotlib.pyplot as plt

# Numpy offers various functions for working with tables of data.
import numpy

# %%
x = numpy.array([2,3,4,5])

y1 = numpy.array([53.8436,125.2976,248.849,525.799])
y2 = numpy.array([0.1112,0.2458,0.4760,0.8360])

# %%
fig = plt.figure(figsize=(10,6))
plt.xticks(np.arange(min(x), max(x)+1, 1.0))

ax = fig.add_subplot(111)
ax.set_title('Samplen van 100 chromatic mazes van verschillende dimensies', fontsize=16)
ax.set_xlabel('Dimensie', fontsize=16)
ax.set_ylabel('Uitvoeringstijd [seconden]', fontsize=16)
ax.plot(x,y1, label="ProbLog")
ax.plot(x,y2, label="AnsProlog | Clingo")
ax.legend(loc=2)
#plt.yscale('log')
plt.savefig('chm_100.pdf')

# %%
fig = plt.figure(figsize=(7,5))
plt.xticks(np.arange(min(x), max(x)+1, 1.0))

ax = fig.add_subplot(111)
ax.set_xlabel('Dimensie', fontsize=12)
ax.set_ylabel('Uitvoeringstijd [seconden]', fontsize=12)
ax.plot(x,y1,'-', color='black', label="ProbLog")
ax.plot(x,y2,'-.', color='black', label="AnsProlog | Clingo")
leg = ax.legend(loc=2,prop={'size':10},fancybox=True)
leg.get_frame().set_alpha(0.5)
plt.yscale('log')
plt.savefig('chm_100_log.pdf')

# %%
x = numpy.array([2,3,4,5])

y1 = numpy.array([20.0200,313,5162.4510,100000])
y2 = numpy.array([0.0114,0.0156,0.0174,0.0204])

fig = plt.figure(figsize=(10,6))
plt.xticks(np.arange(min(x), max(x)+1, 1.0))
ax = fig.add_subplot(111)
ax.set_title('Samplen van 100 perfect mazes van verschillende dimensies', fontsize=16)
ax.set_xlabel('Dimensie', fontsize=16)
ax.set_ylabel('Uitvoeringstijd [seconden]', fontsize=16)
ax.plot(x,y1, label="ProbLog")
ax.plot(x,y2, label="AnsProlog | Clingo")
ax.legend(loc=2)
plt.savefig('pm_100.pdf')

# %%
x = numpy.array([2,3,4,5])

y1 = numpy.array([20.0200,313,5162.4510,100000])
y2 = numpy.array([0.0114,0.0156,0.0174,0.0204])

fig = plt.figure(figsize=(7,5))
plt.xticks(np.arange(min(x), max(x)+1, 1.0))
ax = fig.add_subplot(111)
ax.set_xlabel('Dimensie', fontsize=12)
ax.set_ylabel('Uitvoeringstijd [seconden]', fontsize=12)
ax.plot(x,y1,'-', color='black', label="ProbLog")
ax.plot(x,y2,'-.', color='black', label="AnsProlog | Clingo")
leg = ax.legend(loc=2,prop={'size':10},fancybox=True)
leg.get_frame().set_alpha(0.5)
plt.yscale('log')
plt.savefig('pm_100_log.pdf')

# %%
x = numpy.array([2,3,4,5])

y1 = numpy.array([4.8630,10.1386,18.0220,28.0934])
y2 = numpy.array([0.0130,0.0190,0.0326,0.0538])

fig = plt.figure(figsize=(10,6))
plt.xticks(np.arange(min(x), max(x)+1, 1.0))
ax = fig.add_subplot(111)
ax.set_title('Samplen van 100 dungeons van verschillende dimensies', fontsize=16)
ax.set_xlabel('Dimensie', fontsize=16)
ax.set_ylabel('Uitvoeringstijd [seconden]', fontsize=16)
ax.plot(x,y1, label="ProbLog")
ax.plot(x,y2, label="AnsProlog | Clingo")
ax.legend(loc=2)
plt.savefig('dungeons_100.pdf')

# %%
x = numpy.array([2,3,4,5])

y1 = numpy.array([4.8630,10.1386,18.0220,28.0934])
y2 = numpy.array([0.0130,0.0190,0.0326,0.0538])

fig = plt.figure(figsize=(7,5))
plt.xticks(np.arange(min(x), max(x)+1, 1.0))
ax = fig.add_subplot(111)
ax.set_xlabel('Dimensie', fontsize=12)
ax.set_ylabel('Uitvoeringstijd [seconden]', fontsize=12)
ax.plot(x,y1,'-', color='black', label="ProbLog")
ax.plot(x,y2,'-.', color='black', label="AnsProlog | Clingo")
leg = ax.legend(loc=2,prop={'size':10},fancybox=True)
leg.get_frame().set_alpha(0.5)
plt.yscale('log')
plt.savefig('dungeons_100_log.pdf')

# %%
# Create a subplot. This gives us more options.
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)   
# This number indicates: number of rows*100 + number of columns*10 + index
#  For more than 10 plots, use a tuple (nr, nc, index)

# Width of one bar.
width = 0.4



x=numpy.array([1,2,3])

y1=numpy.array([2,4,3])
y2=numpy.array([2,4,4])

# Set the plot title
ax.set_title('Hoogste dimensie met gegenereerde totaaloplosing', fontsize=16)

# Set the position of the ticks on the x-axis
ax.set_xticks(x+width)
# Set the labels of the ticks on the x-axis
ax.set_xticklabels(['Chromatic Maze', 'Perfect Maze', 'Dungeons'])

# Remove ticks at the secondary x-axis (at the top)
ax.get_xaxis().tick_bottom()    

# Add some range to the y-axis.
ax.set_ylim((0,max(max(y1), max(y2))+0.5))

# Remove both axis lines
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)  


# Draw the bars, this returns the rectangles which we need later.
rectangles1 = ax.bar(x, y1, width, color='#00407A', label='ProbLog',edgecolor="none");
rectangles2 = ax.bar(x+width, y2, width, color='#1D8DB0', label='AnsProlog',edgecolor="none");

# Remove the ticks on Y-axis, we'll label the bars
ax.set_yticks([])

# Replace the ticks by labels on the bars themselves
def autolabel(rects):
     # Attach some text labels
     for rect in rects:
         height = rect.get_height()
         ax.text(rect.get_x() + rect.get_width()/2., 1.01*height,
                 '%d' % int(height),
                 ha='center', va='bottom')

autolabel(rectangles1)
autolabel(rectangles2)

# Add a legend, this uses the 'label' arguments of the 'bar' function.
ax.legend(loc=2);

# Save the figure to PDF
fig.savefig('all_generate_dim.pdf')

# %%
y1 = numpy.array([4.1280,100,3478.7690])
y2 = numpy.array([2.7932,0.0190,0.9406])
x = numpy.array([0,1,2])
fig = plt.figure(figsize=(10,6))
plt.xticks(range(3), ['Chromatic Maze','Perfect Maze','Dungeon'], size='large')
ax = fig.add_subplot(111)
ax.set_title('Tijd per puzzel om alle toekenningen te berekenen (maximum)', fontsize=16)
ax.set_xlabel('', fontsize=16)
ax.set_ylabel('Uitvoeringstijd [seconden]', fontsize=16)
ax.plot(x,y1, label="ProbLog")
ax.plot(x,y2, label="AnsProlog | Clingo")
ax.legend(loc=2)
plt.savefig('all_generate_time.pdf')

# %%
y1 = numpy.array([4.1280,100,3478.7690])
y2 = numpy.array([2.7932,0.0190,0.9406])
x = numpy.array([0,1,2])
fig = plt.figure(figsize=(10,6))
plt.xticks(range(3), ['Chromatic Maze','Perfect Maze','Dungeon'], size='large')
ax = fig.add_subplot(111)
ax.set_title('Tijd per puzzel om alle toekenningen te berekenen (maximum)', fontsize=16)
ax.set_xlabel('', fontsize=16)
ax.set_ylabel('Uitvoeringstijd [seconden]', fontsize=16)
ax.plot(x,y1, label="ProbLog")
ax.plot(x,y2, label="AnsProlog | Clingo")
ax.legend(loc=2)
plt.yscale('log')
plt.savefig('all_generate_time_log.pdf')

# %%
x = numpy.array([2,3,4,5])

y1 = numpy.array([0.247,1.357,11.723,81.820])
y2 = numpy.array([1.616,1000000,1000000,1000000])

fig = plt.figure(figsize=(10,6))
plt.xticks(np.arange(min(x), max(x)+1, 1.0))
ax = fig.add_subplot(111)
ax.set_title('Zonder evidence vs. met evidence | Vereenvoudigde dungeon', fontsize=16)
ax.set_xlabel('Dimensie', fontsize=16)
ax.set_ylabel('Uitvoeringstijd [seconden]', fontsize=16)
ax.plot(x,y1, label="Zonder evidence")
ax.plot(x,y2, label="Met evidence")
ax.legend(loc=2)
#plt.yscale('log')
plt.savefig('evidence_comapare.pdf')

# %%
x = numpy.array([2,3,4,5])

y1 = numpy.array([0.247,1.357,11.723,81.820])
y2 = numpy.array([1.616,1000000,1000000,1000000])

fig = plt.figure(figsize=(10,6))
plt.xticks(np.arange(min(x), max(x)+1, 1.0))
ax = fig.add_subplot(111)
ax.set_title('Zonder evidence vs. met evidence | Vereenvoudigde dungeon', fontsize=16)
ax.set_xlabel('Dimensie', fontsize=16)
ax.set_ylabel('Uitvoeringstijd [seconden]', fontsize=16)
ax.plot(x,y1, label="Zonder evidence")
ax.plot(x,y2, label="Met evidence")
ax.legend(loc=2)
plt.yscale('log')
plt.savefig('evidence_comapare_log.pdf')
